# %%
# change dir so static paths in code will be resolved as in panel app
import os
os.chdir('..')

# %%
from service.data import data_index, get_dataframe
import pandas as pd
import service.dataframe as sdf

# %%
i = data_index()
i
# Out:
# {'camera': [19, 18, 17, 16]}

# %%
df = get_dataframe('camera', 19)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 18 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   cognome_nome                         414 non-null    str
#  1   nome_cognome                         414 non-null    str
#  2   legislatura                          414 non-null    int64
#  3   DATA DI NASCITA                      414 non-null    str
#  4   COMUNE DI NASCITA                    414 non-null    str
#  5   CIRCOSCRIZIONE DI ELEZIONE           414 non-null    str
#  6   COLLEGIO DI ELEZIONE                 406 non-null    str
#  7   LISTA DI ELEZIONE                    280 non-null    str
#  8   PROCLAMAZIONE                        414 non-null    str
#  9   ELEZIONE CONVALIDATA                 397 non-null    str
#  10  FORMAZIONE O NOTE PROFESSIONALI      402 non-null    str
# ...

# %%
sdf.str_to_datetime(df, in_place=False)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 22 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   cognome_nome                            414 non-null    str
#  1   nome_cognome                            414 non-null    str
#  2   legislatura                             414 non-null    int64
#  3   DATA DI NASCITA                         414 non-null    str
#  4   COMUNE DI NASCITA                       414 non-null    str
#  5   CIRCOSCRIZIONE DI ELEZIONE              414 non-null    str
#  6   COLLEGIO DI ELEZIONE                    406 non-null    str
#  7   LISTA DI ELEZIONE                       280 non-null    str
#  8   PROCLAMAZIONE                           414 non-null    str
#  9   ELEZIONE CONVALIDATA                    397 non-null    str
#  10  FORMAZIONE O NOTE PROFESSIONALI         402 non-null    str
# ...
